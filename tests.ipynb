# %%
pip install rds2py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [rds2py]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Select two (or more) cancer types from Mo, CK., et al..
# Load Visium data and corresponding scRNAseq samples (.rds Seurat objects).
# Perform cell type deconvolution of the Visium slides using corresponding scRNAseq as a reference (Example in R: Seurat spatial tutorial). Perform assignment of cell types to spots in a reasonable way.
# Apply a CCI inference method on spatial Visium datasets. Obtain cell-cell interaction networks for each tumour sample. For the inference you can choose one of the two methods:
# CellChat (R package) (github, tutorial, paper)
# COMMOT (python package) (tutorial, paper)
# Compute network centrality metrics (from CellChat or not) of the obtained networks. Compare within cancer type and between cancer types.
# (Optional) Divide the interactions on pro-tumoral and anti-tumoral interactions based on the immune archetype study (Combes, A.J., Samad, B. & Krummel, M.F.). Compute and visualize the distributions of interaction scores, by taking anti-tumoral interaction scores with negative sign and pro-tumoral interaction scores with positive sign.

# %%
from rds2py import read_rds
r_obj = read_rds("data/HT224P1-S1.rds")
# Out:
# /home/lilian/anaconda3/lib/python3.11/site-packages/rds2py/PyRdsReader.py:105: RuntimeWarning: Unsupported R object type: other
#   warn(f"Unsupported R object type: {rtype}", RuntimeWarning)
# /home/lilian/anaconda3/lib/python3.11/site-packages/rds2py/generics.py:145: RuntimeWarning: RDS file contains an unknown class: 'Seurat', returning the dictionary
#   warn(

# %%
print(r_obj)
# Out:
# {'type': 'S4', 'package_name': 'SeuratObject', 'class_name': 'Seurat', 'attributes': {'assays': {'type': 'vector', 'data': [{'type': 'S4', 'package_name': 'SeuratObject', 'class_name': 'Assay', 'attributes': {'counts': {'type': 'S4', 'package_name': 'Matrix', 'class_name': 'dgCMatrix', 'attributes': {'i': {'type': 'integer', 'data': array([  113,   182,   187, ..., 36564, 36565, 36568], dtype=int32), 'attributes': {}, 'class_name': 'integer_vector'}, 'p': {'type': 'integer', 'data': array([      0,     867,    3590, ..., 5509590, 5513058, 5515217],
# ...

# %%
r_obj.keys()
# Out:
# dict_keys(['type', 'package_name', 'class_name', 'attributes'])

# %%
for key in r_obj.keys():
    if  isinstance(r_obj[key],dict):
        print(key)
        print(r_obj[key].keys())
# Out:
# attributes
# dict_keys(['assays', 'meta.data', 'active.assay', 'active.ident', 'graphs', 'neighbors', 'reductions', 'images', 'project.name', 'misc', 'version', 'commands', 'tools'])

# %%
r_obj["attributes"]["assays"]
# Out:
# {'type': 'vector',
#  'data': [{'type': 'S4',
#    'package_name': 'SeuratObject',
#    'class_name': 'Assay',
#    'attributes': {'counts': {'type': 'S4',
#      'package_name': 'Matrix',
#      'class_name': 'dgCMatrix',
#      'attributes': {'i': {'type': 'integer',
#        'data': array([  113,   182,   187, ..., 36564, 36565, 36568], dtype=int32),
#        'attributes': {},
#        'class_name': 'integer_vector'},
#       'p': {'type': 'integer',
#        'data': array([      0,     867,    3590, ..., 5509590, 5513058, 5515217],
#              dtype=int32),
#        'attributes': {},
#        'class_name': 'integer_vector'},
#       'Dim': {'type': 'integer',
#        'data': array([36601,  2798], dtype=int32),
#        'attributes': {},
#        'class_name': 'integer_vector'},
#       'Dimnames': {'type': 'vector',
#        'data': [{'type': 'string',
#          'data': ['MIR1302-2HG',
#           'FAM138A',
#           'OR4F5',
#           'AL627309.1',
# ...
